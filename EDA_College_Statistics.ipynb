# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np 
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv("college_statistics.csv")

# %%
df.head()
# Out:
#    Rank                                University_Name       State Region  \
# 0     1                              Auburn University     Alabama  South
# 1     1                    University Alaska Fairbanks      Alaska   West
# 2     1  Embry Riddle Aeronautical University Prescott     Arizona   West
# 3     1                            University Arkansas    Arkansas  South
# 4     1                            Harvey Mudd College  California   West
#
#              Division  Early_Career_Pay  Mid_Career_Pay  \
# 0  East South Central             54400          104500
# 1             Pacific             59100          101800
# 2            Mountain             65600          117900
# 3  West South Central             52500           98000
# 4             Pacific             88800          158200
#
#    Make_World_Better_Percent  Stem_Percent     Type  ...  \
# 0                       51.0            31   Public  ...
# 1                       54.0            20   Public  ...
# 2                       59.0            43  Private  ...
# 3                       49.0            18   Public  ...
# 4                       55.0            85  Private  ...
#
#   Black_Diversity_Percent  Hispanic_Diversity_Percent  \
# 0                    0.07                        0.02
# 1                    0.02                        0.05
# 2                    0.02                        0.06
# 3                    0.05                        0.06
# 4                    0.02                        0.10
#
#    Native_Hawaiian_Pacific_Islander_Diversity_Percent  \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.01
# 3                                               0.00
# 4                                               0.00
#
#    Two_Or_More_Races_Diversity_Percent  Total_Minority_Diversity_Percent  \
# 0                                 0.00                              0.13
# 1                                 0.04                              0.24
# 2                                 0.09                              0.23
# 3                                 0.03                              0.18
# 4                                 0.06                              0.39
#
#    Non-Resident_Foreign_Diversity_Percent  Unknown_Diversity_Percent  \
# 0                                    0.06                       0.01
# 1                                    0.03                       0.28
# 2                                    0.10                       0.10
# 3                                    0.06                       0.01
# 4                                    0.13                       0.05
#
#    White_Diversity_Percent  Women_Diversity_Percent  Men_Diversity_Percent
# 0                     0.81                     0.49                   0.51
# 1                     0.45                     0.58                   0.42
# 2                     0.57                     0.23                   0.77
# 3                     0.76                     0.51                   0.49
# 4                     0.44                     0.46                   0.54
#
# [5 rows x 28 columns]

# %%
df.drop('Rank',inplace=True, axis=1)
df.head()
# Out:
#                                  University_Name       State Region  \
# 0                              Auburn University     Alabama  South
# 1                    University Alaska Fairbanks      Alaska   West
# 2  Embry Riddle Aeronautical University Prescott     Arizona   West
# 3                            University Arkansas    Arkansas  South
# 4                            Harvey Mudd College  California   West
#
#              Division  Early_Career_Pay  Mid_Career_Pay  \
# 0  East South Central             54400          104500
# 1             Pacific             59100          101800
# 2            Mountain             65600          117900
# 3  West South Central             52500           98000
# 4             Pacific             88800          158200
#
#    Make_World_Better_Percent  Stem_Percent     Type Degree_Length  ...  \
# 0                       51.0            31   Public        4 Year  ...
# 1                       54.0            20   Public        4 Year  ...
# 2                       59.0            43  Private        4 Year  ...
# 3                       49.0            18   Public        4 Year  ...
# 4                       55.0            85  Private        4 Year  ...
#
#    Black_Diversity_Percent  Hispanic_Diversity_Percent  \
# 0                     0.07                        0.02
# 1                     0.02                        0.05
# 2                     0.02                        0.06
# 3                     0.05                        0.06
# 4                     0.02                        0.10
#
#    Native_Hawaiian_Pacific_Islander_Diversity_Percent  \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.01
# 3                                               0.00
# 4                                               0.00
#
#    Two_Or_More_Races_Diversity_Percent  Total_Minority_Diversity_Percent  \
# 0                                 0.00                              0.13
# 1                                 0.04                              0.24
# 2                                 0.09                              0.23
# 3                                 0.03                              0.18
# 4                                 0.06                              0.39
#
#    Non-Resident_Foreign_Diversity_Percent  Unknown_Diversity_Percent  \
# 0                                    0.06                       0.01
# 1                                    0.03                       0.28
# 2                                    0.10                       0.10
# 3                                    0.06                       0.01
# 4                                    0.13                       0.05
#
#    White_Diversity_Percent  Women_Diversity_Percent  Men_Diversity_Percent
# 0                     0.81                     0.49                   0.51
# 1                     0.45                     0.58                   0.42
# 2                     0.57                     0.23                   0.77
# 3                     0.76                     0.51                   0.49
# 4                     0.44                     0.46                   0.54
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (907, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   University_Name                                     907 non-null    object
#  1   State                                               907 non-null    object
#  2   Region                                              907 non-null    object
#  3   Division                                            907 non-null    object
#  4   Early_Career_Pay                                    907 non-null    int64
#  5   Mid_Career_Pay                                      907 non-null    int64
#  6   Make_World_Better_Percent                           878 non-null    float64
#  7   Stem_Percent                                        907 non-null    int64
#  8   Type                                                907 non-null    object
#  9   Degree_Length                                       907 non-null    object
#  10  Room_And_Board                                      857 non-null    float64
#  11  In_State_Tuition                                    907 non-null    int64
#  12  In_State_Total                                      907 non-null    int64
#  13  Out_Of_State_Tuition                                907 non-null    int64
#  14  Out_Of_State_Total                                  907 non-null    int64
#  15  American_Indian_Alaska_Native_Diversity_Percent     880 non-null    float64
#  16  Asian_Diversity_Percent                             880 non-null    float64
#  17  Black_Diversity_Percent                             880 non-null    float64
#  18  Hispanic_Diversity_Percent                          880 non-null    float64
#  19  Native_Hawaiian_Pacific_Islander_Diversity_Percent  880 non-null    float64
#  20  Two_Or_More_Races_Diversity_Percent                 880 non-null    float64
#  21  Total_Minority_Diversity_Percent                    880 non-null    float64
#  22  Non-Resident_Foreign_Diversity_Percent              880 non-null    float64
#  23  Unknown_Diversity_Percent                           880 non-null    float64
#  24  White_Diversity_Percent                             880 non-null    float64
#  25  Women_Diversity_Percent                             880 non-null    float64
#  26  Men_Diversity_Percent                               880 non-null    float64
# dtypes: float64(14), int64(7), object(6)
# memory usage: 191.4+ KB

# %%
df.describe()
# Out:
#        Early_Career_Pay  Mid_Career_Pay  Make_World_Better_Percent  \
# count        907.000000      907.000000                 878.000000
# mean       51259.647189    92639.029768                  53.697039
# std         8212.065310    15615.471694                   9.046782
# min        32500.000000    60100.000000                  33.000000
# 25%        46000.000000    81550.000000                  48.000000
# 50%        49900.000000    89900.000000                  52.000000
# 75%        55500.000000   100600.000000                  58.000000
# max        91200.000000   158200.000000                  94.000000
#
#        Stem_Percent  Room_And_Board  In_State_Tuition  In_State_Total  \
# count    907.000000      857.000000        907.000000      907.000000
# mean      16.984564    10839.107351      24948.081588    35189.663727
# std       15.198386     2759.601286      16009.137788    18298.597566
# min        0.000000     1698.000000       1420.000000     1420.000000
# 25%        7.000000     8934.000000       9812.000000    19322.500000
# 50%       14.000000    10500.000000      21690.000000    30512.000000
# 75%       23.000000    12720.000000      38230.000000    49939.500000
# max      100.000000    19200.000000      59985.000000    75003.000000
#
#        Out_Of_State_Tuition  Out_Of_State_Total  \
# count            907.000000          907.000000
# mean           30288.971334        40530.553473
# std            12573.202715        15240.203870
# min             4118.000000         6670.000000
# 25%            20581.500000        29460.000000
# 50%            28512.000000        38777.000000
# 75%            39367.000000        51266.000000
# max            59985.000000        75003.000000
#
#        American_Indian_Alaska_Native_Diversity_Percent  ...  \
# count                                       880.000000  ...
# mean                                          0.006909  ...
# std                                           0.019175  ...
# min                                           0.000000  ...
# 25%                                           0.000000  ...
# 50%                                           0.000000  ...
# 75%                                           0.010000  ...
# max                                           0.230000  ...
#
#        Black_Diversity_Percent  Hispanic_Diversity_Percent  \
# count               880.000000                  880.000000
# mean                  0.117182                    0.070500
# std                   0.171413                    0.068996
# min                   0.000000                    0.000000
# 25%                   0.030000                    0.030000
# 50%                   0.060000                    0.050000
# 75%                   0.120000                    0.080000
# max                   0.990000                    0.630000
#
#        Native_Hawaiian_Pacific_Islander_Diversity_Percent  \
# count                                         880.000000
# mean                                            0.001636
# std                                             0.008681
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             0.160000
#
#        Two_Or_More_Races_Diversity_Percent  Total_Minority_Diversity_Percent  \
# count                           880.000000                        880.000000
# mean                              0.030023                          0.270591
# std                               0.026144                          0.180953
# min                               0.000000                          0.030000
# 25%                               0.020000                          0.150000
# 50%                               0.030000                          0.230000
# 75%                               0.040000                          0.330000
# max                               0.300000                          1.000000
#
#        Non-Resident_Foreign_Diversity_Percent  Unknown_Diversity_Percent  \
# count                              880.000000                 880.000000
# mean                                 0.058636                   0.053239
# std                                  0.065831                   0.058850
# min                                  0.000000                   0.000000
# 25%                                  0.020000                   0.020000
# 50%                                  0.040000                   0.040000
# 75%                                  0.080000                   0.070000
# max                                  0.680000                   0.630000
#
#        White_Diversity_Percent  Women_Diversity_Percent  Men_Diversity_Percent
# count               880.000000               880.000000             880.000000
# mean                  0.619557                 0.561511               0.439466
# std                   0.193429                 0.121317               0.121346
# min                   0.000000                 0.000000               0.000000
# 25%                   0.540000                 0.510000               0.390000
# 50%                   0.660000                 0.560000               0.440000
# 75%                   0.760000                 0.610000               0.490000
# max                   0.950000                 1.000000               1.000000
#
# [8 rows x 21 columns]

# %%
fig,ax = plt.subplots(1,figsize=(20,10))
sns.boxplot( y=df["Early_Career_Pay"], x=df["State"] )
# Out:
# <AxesSubplot:xlabel='State', ylabel='Early_Career_Pay'>

# %%
fig,ax = plt.subplots(1,figsize=(10,20))
ordered = df.groupby(by=["State"])["Early_Career_Pay"].median().sort_values()
sns.boxplot(data=df, x="Early_Career_Pay", y="State", order=ordered.index )
# Out:
# <AxesSubplot:xlabel='Early_Career_Pay', ylabel='State'>

# %%
fig,ax = plt.subplots(1,figsize=(20,10))
ordered = df.groupby(by=["Region"])["Early_Career_Pay"].median().sort_values()
sns.boxplot(data=df, y="Early_Career_Pay", x="Region", order=ordered.index )
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Early_Career_Pay'>

# %%
fig,ax = plt.subplots(1,figsize=(15,10))
sns.boxplot( y=df["Early_Career_Pay"], x=df["Division"] )
# Out:
# <AxesSubplot:xlabel='Division', ylabel='Early_Career_Pay'>

# %%
fig,ax = plt.subplots(1,figsize=(15,10))
ordered = df.groupby(by=["Division"])["Early_Career_Pay"].median().sort_values()
sns.boxplot( data = df,y="Early_Career_Pay", x="Division", order=ordered.index)
# Out:
# <AxesSubplot:xlabel='Division', ylabel='Early_Career_Pay'>

# %%
df.groupby(by=["Division"])["Early_Career_Pay"].median().sort_values()
# Out:
# Division
# East South Central    45000.0
# West North Central    47900.0
# West South Central    47900.0
# South Atlantic        48750.0
# Mountain              50250.0
# East North Central    51250.0
# New England           52900.0
# Pacific               54550.0
# Middle Atlantic       58750.0
# Name: Early_Career_Pay, dtype: float64

# %%
fig,ax = plt.subplots(1,figsize=(10,10))
sns.boxplot( y=df["Early_Career_Pay"], x=df["Degree_Length"] )
# Out:
# <AxesSubplot:xlabel='Degree_Length', ylabel='Early_Career_Pay'>

# %%
fig,ax = plt.subplots(1,figsize=(10,10))
sns.boxplot( y=df["Early_Career_Pay"], x=df["Type"] )
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Early_Career_Pay'>

# %%
sns.pairplot(data=df,vars=["Early_Career_Pay","Region", "Division", "Make_World_Better_Percent" , "Stem_Percent" ])

# %%
fig,ax = plt.subplots(1,figsize=(10,10))
sns.scatterplot(data=df, y="Early_Career_Pay", x="In_State_Total",hue='Degree_Length' )
# Out:
# <AxesSubplot:xlabel='In_State_Total', ylabel='Early_Career_Pay'>

# %%
fig,ax = plt.subplots(1,figsize=(10,10))
sns.scatterplot(data=df, y="Early_Career_Pay", x="In_State_Total",hue='Region' )
# Out:
# <AxesSubplot:xlabel='In_State_Total', ylabel='Early_Career_Pay'>

# %%
sns.lmplot(data=df, y="Early_Career_Pay", x="In_State_Total", line_kws = {'color':'g'},hue='Type')

# %%
g=sns.FacetGrid(df,col="Region", hue="Type")
g.map(sns.scatterplot,"In_State_Total", "Early_Career_Pay")
g.add_legend()

# %%
fig,ax = plt.subplots(1,figsize=(10,10))
sns.scatterplot(data=df, y="Early_Career_Pay", x="Out_Of_State_Total")
# Out:
# <AxesSubplot:xlabel='Out_Of_State_Total', ylabel='Early_Career_Pay'>

# %%
fig,ax = plt.subplots(1,figsize=(10,10))
sns.scatterplot(data=df, y="Early_Career_Pay", x="Out_Of_State_Total", hue='Region')
# Out:
# <AxesSubplot:xlabel='Out_Of_State_Total', ylabel='Early_Career_Pay'>

# %%
fig,ax = plt.subplots(1,figsize=(10,10))
sns.scatterplot(data=df, y="Early_Career_Pay", x="Out_Of_State_Total", hue='Type')
# Out:
# <AxesSubplot:xlabel='Out_Of_State_Total', ylabel='Early_Career_Pay'>

# %%
g=sns.FacetGrid(df,col="Region", hue="Type")
g.map(sns.scatterplot,"Out_Of_State_Total", "Early_Career_Pay")
g.add_legend()

# %%
sns.lmplot(data=df, y="Early_Career_Pay", x="Stem_Percent", line_kws = {'color':'g'},hue='Region')

# %%
sns.lmplot(data=df, y="Early_Career_Pay", x="Make_World_Better_Percent", line_kws = {'color':'g'},hue='Region')

# %%
#sns.lmplot(data=df, x="Room_And_Board", y="Early_Career_Pay",hue="Type", col="Region")

# %%
g=sns.FacetGrid(df,col="Region", hue="Type")
g.map(sns.scatterplot,"Room_And_Board", "Early_Career_Pay")
g.add_legend()

# %%
df.groupby('State')['Early_Career_Pay'].mean()
# Out:
# State
# Alabama           44992.000000
# Alaska            55133.333333
# Arizona           51600.000000
# Arkansas          44110.526316
# California        67232.000000
# Colorado          50341.176471
# Connecticut       54584.210526
# Delaware          49040.000000
# Florida           50865.217391
# Georgia           49280.000000
# Hawaii            47700.000000
# Idaho             48957.142857
# Illinois          54937.500000
# Indiana           52458.333333
# Iowa              48240.000000
# Kansas            45608.695652
# Kentucky          43620.000000
# Louisiana         47200.000000
# Maine             47594.117647
# Maryland          53800.000000
# Massachusetts     63100.000000
# Michigan          52172.000000
# Minnesota         51604.166667
# Mississippi       42042.857143
# Missouri          49096.000000
# Montana           47212.500000
# Nebraska          47072.222222
# Nevada            52366.666667
# New Hampshire     50707.692308
# New Jersey        54808.333333
# New Mexico        48350.000000
# New York          65495.652174
# North Carolina    49640.000000
# North Dakota      45622.222222
# Ohio              52900.000000
# Oklahoma          46218.181818
# Oregon            49504.347826
# Pennsylvania      60644.000000
# Rhode Island      54890.000000
# South Carolina    45376.000000
# South Dakota      47110.000000
# Tennessee         47936.000000
# Texas             57387.500000
# Utah              53000.000000
# Vermont           48738.461538
# Virginia          53620.000000
# Washington        52773.913043
# West Virginia     44594.444444
# Wisconsin         50458.333333
# Wyoming           52400.000000
# Name: Early_Career_Pay, dtype: float64

# %%
df.groupby('State')['Early_Career_Pay'].median()
# Out:
# State
# Alabama           44500.0
# Alaska            56000.0
# Arizona           52050.0
# Arkansas          44100.0
# California        63400.0
# Colorado          48300.0
# Connecticut       53100.0
# Delaware          46300.0
# Florida           49600.0
# Georgia           46800.0
# Hawaii            48500.0
# Idaho             50100.0
# Illinois          53250.0
# Indiana           49850.0
# Iowa              48000.0
# Kansas            45200.0
# Kentucky          44300.0
# Louisiana         47450.0
# Maine             46100.0
# Maryland          51150.0
# Massachusetts     62500.0
# Michigan          50800.0
# Minnesota         51100.0
# Mississippi       41150.0
# Missouri          46900.0
# Montana           46250.0
# Nebraska          47950.0
# Nevada            52700.0
# New Hampshire     48900.0
# New Jersey        52350.0
# New Mexico        46450.0
# New York          63500.0
# North Carolina    46600.0
# North Dakota      46400.0
# Ohio              51800.0
# Oklahoma          45150.0
# Oregon            50000.0
# Pennsylvania      58500.0
# Rhode Island      53750.0
# South Carolina    43500.0
# South Dakota      45950.0
# Tennessee         46500.0
# Texas             56300.0
# Utah              53150.0
# Vermont           48800.0
# Virginia          52300.0
# Washington        53600.0
# West Virginia     43900.0
# Wisconsin         49100.0
# Wyoming           52400.0
# Name: Early_Career_Pay, dtype: float64

# %%
df.groupby('Region')['Early_Career_Pay'].mean()
# Out:
# Region
# Midwest      50254.687500
# Northeast    56824.260355
# South        48352.023121
# West         53633.823529
# Name: Early_Career_Pay, dtype: float64

# %%
df.groupby('Region')['Early_Career_Pay'].median()
# Out:
# Region
# Midwest      49400.0
# Northeast    56000.0
# South        47300.0
# West         52250.0
# Name: Early_Career_Pay, dtype: float64

# %%
df.groupby('Division')['Early_Career_Pay'].mean()
# Out:
# Division
# East North Central    52584.426230
# East South Central    44969.662921
# Middle Atlantic       60248.611111
# Mountain              50167.857143
# New England           54282.474227
# Pacific               56060.000000
# South Atlantic        49746.470588
# West North Central    48133.582090
# West South Central    49087.356322
# Name: Early_Career_Pay, dtype: float64

# %%
df.groupby('Division')['Early_Career_Pay'].median()
# Out:
# Division
# East North Central    51250.0
# East South Central    45000.0
# Middle Atlantic       58750.0
# Mountain              50250.0
# New England           52900.0
# Pacific               54550.0
# South Atlantic        48750.0
# West North Central    47900.0
# West South Central    47900.0
# Name: Early_Career_Pay, dtype: float64

# %%
df.corrwith(df['Early_Career_Pay']).sort_values()
# Out:
# Women_Diversity_Percent                              -0.404248
# Black_Diversity_Percent                              -0.278422
# Make_World_Better_Percent                            -0.214997
# American_Indian_Alaska_Native_Diversity_Percent      -0.168149
# White_Diversity_Percent                              -0.126923
# Native_Hawaiian_Pacific_Islander_Diversity_Percent   -0.045234
# Unknown_Diversity_Percent                            -0.026837
# Total_Minority_Diversity_Percent                     -0.025574
# Two_Or_More_Races_Diversity_Percent                   0.133387
# Hispanic_Diversity_Percent                            0.164137
# In_State_Tuition                                      0.390608
# Men_Diversity_Percent                                 0.404925
# In_State_Total                                        0.423822
# Non-Resident_Foreign_Diversity_Percent                0.467769
# Out_Of_State_Tuition                                  0.553600
# Out_Of_State_Total                                    0.555280
# Asian_Diversity_Percent                               0.580966
# Stem_Percent                                          0.601225
# Room_And_Board                                        0.608899
# Mid_Career_Pay                                        0.982915
# Early_Career_Pay                                      1.000000
# dtype: float64

# %% [markdown]
# ## Correlation analysis
#
# ### Positive correlation
# - In_State_Tuition                                      0.390608
# - Men_Diversity_Percent                                 0.404925
# - In_State_Total                                        0.423822
# - Non-Resident_Foreign_Diversity_Percent                0.467769
# - Out_Of_State_Tuition                                  0.553600
# - Out_Of_State_Total                                    0.555280
# - Asian_Diversity_Percent                               0.580966
# - Stem_Percent                                          0.601225
# - Room_And_Board                                        0.608899
#
# ### Negative correlation
# - Women_Diversity_Percent                              -0.404248
# - Black_Diversity_Percent                              -0.278422
# - Make_World_Better_Percent                            -0.214997
